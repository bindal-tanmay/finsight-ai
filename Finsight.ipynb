# %% [markdown]
# <a href="https://colab.research.google.com/github/bindal-tanmay/finsight-ai/blob/main/Finsight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install -y zstd
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 3 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 0s (7,361 kB/s)
# Selecting previously unselected package zstd.
# (Reading database ... 118243 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
import subprocess
import time

ollama_process = subprocess.Popen(['ollama', 'serve'])
time.sleep(5)  # give the server a moment to start
print("Ollama server running")
# Out:
# Ollama server running

# %%
# !ollama pull gemma3:1b

# %%
# !ollama run gemma3:1b "What is artificial intelligence?"
# Out:
# Let’s break down Artificial Intelligence! It's a really fascinating and qui
# quickly evolving topic, so here's the explanation broken down into digestib
# digestible pieces.
#
# **At its core:**
#
# * **Artificial Intelligence (AI)** refers to computers being designed to th
# think like people – that is, perform actions and tasks cognitatively equiva
# equivalent to humans in their thinking, learning, problem-solving, includin
# including creativity. Basically, it's about creating computer systems capab
# capable of intelligent behavior.  It’s not necessarily about *replacing* hu
# human intelligence (yet!), but more automating cognitive processes with mac
# machines.
#
#
# **Here's a deeper look at the different aspects and levels:**
#
# 1. **Types & Levels of AI – It's Not All One Level!**: There are various ty
# types, but here are some key levels:
#    * **Narrow/Weak Artificial Intelligence (ANI):** *This is most common to
# today*.  It’s focused on doing specific tasks exceptionally well. Think adv
# advanced voice assistant features ("Alexa," "Siri"), facial recognition on
# a phone, or recommending your next movie. It can *fool you into thinking it
# it understands* things, but it's generally limited to one particular task.
#    - **GENERAL/Strong Artificial Intelligence (AGI):** *Hypothetical, doesn
# doesn’t yet exist*. An AGI system would be able to understand, learn, adapt
# adapt IQ, and apply its knowledge in any intellectual situation – just like
# like a human can. That's the dream of AI researchers – creating something t
# truly intelligent across diverse domains.
#     - **Superintelligence:**  The *most advanced level* (and hotly debated)
# debated), suggesting that an AI could eventually surpass all human intellig
# intelligence in every way – solving grand challenges, developing new techno
# technologies we couldn’t currently imagine.
#
#
# 2. **Techniques Behind AI - How do these systems *think*?** It comes down t
# to a bunch of things:
#    - **Data Analysis:** Most modern AI relies heavily on large datasets – m
# mountains of information for computers to learn from.
#    - **Machine Learning (ML):** The most powerful technique for AI today.
# Instead of explicitly programming every detail, ML algorithms *automaticall
# *automatically learn patterns* from data and adjust their behavior based so
# solely on the data. There are many types:
#       *   **Supervised Learning:** Training a model using labeled examples
# (e.g., feeding it pictures of cats & dogs to tell it which is each).  Good
# for prediction tasks (like spam detection or loan approval.)
#       - **Unsupervised Learning:** Discovering patterns in unlabeled data –
# – like clustering customers together into groups based on their buying habi
# habits. Useful for finding new insights and creating models automatically.
#          *    **Reinforcement learning** : an "AI learns to do something by
# by trial and error". For example, training a robot arm so that it gets bett
# better by performing certain steps with some feedback from humans or automa
# automated systems.
#
#
# 3. **Specific Areas where AI's Being Applied:**
#    -  **Computer Vision (Image Recognition & Analysis):** AI analyzes image
# images and videos to identify what’s *in* them – like facial detection, sel
# self driving auto-pilots
#    -  **Robotics:** Controlling physical robots using sensor data and softw
# software.
#    - **Chatbots & Conversational AI:**  Handling conversations with humans
# - creating automated customer service tools or personal assistants.
#      -  **Natural Language Processing (NLP)**: Allows computers to understa
# understand, interpret, and generate human language -- so things like transl
# translation, speech recognition
#
# 4. **Narrowly Applied AI today:** These are the examples you use daily.
#
#
#
# ---
#
#
# Now that we’ve gone through a bit about what it *is*, here's when some of t
# this concept pops up with popular trends:
#
#
# **Trends Shaping AI Today**:
# *   **Explainable AI (XAI)** - Making how an AI reaches its conclusion clea
# clear and understandaable to humans. A large part is being needed for accou
# accountability when AI systems make decisions.
#
# I hope that provides a good explanation of Artificial Intelligence! Would y
# you like me to:
#
# * Dive deeper into one particular aspect (like machine learning)?
# * Provide examples?
